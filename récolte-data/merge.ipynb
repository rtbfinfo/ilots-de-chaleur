# %%
import geopandas as gpd
import pandas as pd

# %%
cities = ["namur", "liege", "tournai", "charleroi", "mons","bxl"]
every = pd.DataFrame()
for city in cities:
    test = gpd.read_file(f"../data/final_data_Used/secteurs/{city}_secteur.geojson")

    test["city"] = city
    every = pd.concat([every, test], ignore_index=True)

every.to_file(f"../data/secteur_every_city.json", driver="GeoJSON")
every
# Out:
#       ogc_fid  cd_sector    tx_sector_descr_nl     tx_sector_descr_fr  \
# 0       18901  92094A001        HOTEL DE VILLE         HOTEL DE VILLE
# 1       18902  92094A011                   NaN                    NaN
# 2       18903  92094A02-            LE GROGNON             LE GROGNON
# 3       18904  92094A031       PARC - FACULTES        PARC - FACULTES
# 4       18905  92094A04-  PIED DE LA CITADELLE   PIED DE LA CITADELLE
# ...       ...        ...                   ...                    ...
# 1733     2717  21019A441          FAZANTENPARK            FAISANDERIE
# 1734     2718  21019A45-           SCHROEFLAAN  HELICE (AVENUE DE L')
# 1735     2719  21019A492                   BOS                   BOIS
# 1736     2720  21019A51-  SINT-MICHIELSCOLLEGE   COLLEGE SAINT-MICHEL
# 1737     2721  21019A52-          HERTOGSTRAAT              DUC (RUE)
#
#          tx_sector_descr_de cd_sub_munty      tx_sub_munty_nl  \
# 0            HOTEL DE VILLE       92094A                NAMUR
# ...

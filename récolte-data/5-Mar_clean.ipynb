# %%
import pandas as pd

# %%
every = pd.DataFrame()

test = pd.ExcelFile("../data/MAR_predi.xlsx")
cities = ["Charleroi", "Liège", "Namur", "Mons", "Tournai"]
for city in cities: 
    df = pd.read_excel(test, sheet_name="Charleroi")
    df2 = df.iloc[:,25:37]
    df2.drop(["Unnamed: 29","Unnamed: 33"],axis=1, inplace=True)
    df2["Unnamed: 25"] = pd.to_datetime(df2["Unnamed: 25"], format="%Y")
    df2.dropna(inplace=True)
    df2["city"] = city
    every = pd.concat([every, df2], ignore_index=True)

every
every.to_csv("../data/mar_clean.csv")
# Out:
# C:\Users\Décrypte\AppData\Local\Temp\ipykernel_2136\2252929469.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(["Unnamed: 29","Unnamed: 33"],axis=1, inplace=True)
# C:\Users\Décrypte\AppData\Local\Temp\ipykernel_2136\2252929469.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Unnamed: 25"] = pd.to_datetime(df2["Unnamed: 25"], format="%Y")
# C:\Users\Décrypte\AppData\Local\Temp\ipykernel_2136\2252929469.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
